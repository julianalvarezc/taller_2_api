# %% [markdown]
# Tabla con 100 paises obtenidos de la api, en los cuales se ve el nombre del pais, capital, region, poblacion, area e idiomas.

# %%
import pandas as pd
import sys

sys.path.append('../src') 
from app import get_api_data
api = get_api_data()

# 2. Extraer campos relevantes
rows = []
for country in api:
    name = country.get('name', {}).get('common', 'N/A')
    capital = country.get('capital', ['N/A'])[0]
    region = country.get('region', 'N/A')
    population = country.get('population', 'N/A')
    area = country.get('area', 'N/A')
    languages = ', '.join(country.get('languages', {}).values()) if 'languages' in country else 'N/A'

    rows.append({
        'País': name,
        'Capital': capital,
        'Región': region,
        'Población': population,
        'Área (km²)': area,
        'Idiomas': languages
    })

# 3. Crear el DataFrame
df = pd.DataFrame(rows)
df.head(100)
# Out:
#                                  País      Capital     Región  Población  \
# 0                            Mongolia   Ulan Bator       Asia    3278292
# 1                              Panama  Panama City   Americas    4314768
# 2                               Tonga   Nuku'alofa    Oceania     105697
# 3                             Comoros       Moroni     Africa     869595
# 4                              Sweden    Stockholm     Europe   10353442
# ..                                ...          ...        ...        ...
# 95                           Dominica       Roseau   Americas      71991
# 96                            Finland     Helsinki     Europe    5530719
# 97                        South Korea        Seoul       Asia   51780579
# 98  Heard Island and McDonald Islands          N/A  Antarctic          0
# 99                      Faroe Islands     Tórshavn     Europe      48865
#
#     Área (km²)                   Idiomas
# 0    1564110.0                 Mongolian
# 1      75417.0                   Spanish
# 2        747.0           English, Tongan
# 3       1862.0  Arabic, French, Comorian
# 4     450295.0                   Swedish
# ..         ...                       ...
# 95       751.0                   English
# 96    338424.0          Finnish, Swedish
# 97    100210.0                    Korean
# 98       412.0                   English
# 99      1393.0           Danish, Faroese
#
# [100 rows x 6 columns]

# %% [markdown]
# Todos los datos que contiene la api por pais, en este caso chile.

# %%
# 2. Seleccionar el primer resultado (Chile)
country = api[0]

# 3. Aplanar los datos para mostrarlos en un DataFrame
def flatten_dict(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            items.append((new_key, ', '.join(str(i) for i in v)))
        else:
            items.append((new_key, v))
    return dict(items)

flat_data = flatten_dict(country)

# 4. Convertir a DataFrame para visualización
df = pd.DataFrame(list(flat_data.items()), columns=["Categoría", "Valor"])

# 5. Mostrar el DataFrame completo
pd.set_option('display.max_rows', None)  # Mostrar todas las filas
df
# Out:
#                        Categoría  \
# 0                    name.common
# 1                  name.official
# 2   name.nativeName.mon.official
# 3     name.nativeName.mon.common
# 4                            tld
# 5                           cca2
# 6                           ccn3
# 7                           cioc
# 8                    independent
# 9                         status
# 10                      unMember
# 11         currencies.MNT.symbol
# 12           currencies.MNT.name
# 13                      idd.root
# 14                  idd.suffixes
# 15                       capital
# 16                  altSpellings
# 17                        region
# 18                     subregion
# 19                 languages.mon
# 20                        latlng
# 21                    landlocked
# 22                       borders
# 23                          area
# 24                demonyms.eng.f
# 25                demonyms.eng.m
# 26                demonyms.fra.f
# 27                demonyms.fra.m
# 28                          cca3
# 29     translations.ara.official
# 30       translations.ara.common
# 31     translations.bre.official
# 32       translations.bre.common
# 33     translations.ces.official
# 34       translations.ces.common
# 35     translations.cym.official
# 36       translations.cym.common
# 37     translations.deu.official
# 38       translations.deu.common
# 39     translations.est.official
# 40       translations.est.common
# 41     translations.fin.official
# 42       translations.fin.common
# 43     translations.fra.official
# 44       translations.fra.common
# 45     translations.hrv.official
# 46       translations.hrv.common
# 47     translations.hun.official
# 48       translations.hun.common
# 49     translations.ind.official
# 50       translations.ind.common
# 51     translations.ita.official
# 52       translations.ita.common
# 53     translations.jpn.official
# 54       translations.jpn.common
# 55     translations.kor.official
# 56       translations.kor.common
# 57     translations.nld.official
# 58       translations.nld.common
# 59     translations.per.official
# 60       translations.per.common
# 61     translations.pol.official
# 62       translations.pol.common
# 63     translations.por.official
# 64       translations.por.common
# 65     translations.rus.official
# 66       translations.rus.common
# 67     translations.slk.official
# 68       translations.slk.common
# 69     translations.spa.official
# 70       translations.spa.common
# 71     translations.srp.official
# 72       translations.srp.common
# 73     translations.swe.official
# 74       translations.swe.common
# 75     translations.tur.official
# 76       translations.tur.common
# 77     translations.urd.official
# 78       translations.urd.common
# 79     translations.zho.official
# 80       translations.zho.common
# 81                          flag
# 82               maps.googleMaps
# 83           maps.openStreetMaps
# 84                    population
# 85                     gini.2018
# 86                          fifa
# 87                     car.signs
# 88                      car.side
# 89                     timezones
# 90                    continents
# 91                     flags.png
# 92                     flags.svg
# 93                     flags.alt
# 94                coatOfArms.png
# 95                coatOfArms.svg
# 96                   startOfWeek
# 97            capitalInfo.latlng
# 98             postalCode.format
# 99              postalCode.regex
#
#                                                 Valor
# 0                                            Mongolia
# 1                                            Mongolia
# 2                                          Монгол улс
# 3                                          Монгол улс
# 4                                                 .mn
# 5                                                  MN
# 6                                                 496
# 7                                                 MGL
# 8                                                True
# 9                                 officially-assigned
# 10                                               True
# 11                                                  ₮
# 12                                   Mongolian tögrög
# 13                                                 +9
# 14                                                 76
# 15                                         Ulan Bator
# 16                                                 MN
# 17                                               Asia
# 18                                       Eastern Asia
# 19                                          Mongolian
# 20                                        46.0, 105.0
# 21                                               True
# 22                                           CHN, RUS
# 23                                          1564110.0
# 24                                          Mongolian
# 25                                          Mongolian
# 26                                            Mongole
# 27                                             Mongol
# 28                                                MNG
# 29                                    جمهورية منغوليا
# 30                                            منغوليا
# 31                                           Mongolia
# 32                                           Mongolia
# 33                                     Stát Mongolsko
# 34                                          Mongolsko
# 35                                           Mongolia
# 36                                           Mongolia
# 37                                           Mongolei
# 38                                           Mongolei
# 39                                          Mongoolia
# 40                                          Mongoolia
# 41                                Mongolian tasavalta
# 42                                           Mongolia
# 43                                           Mongolie
# 44                                           Mongolie
# 45                                          Mongolija
# 46                                          Mongolija
# 47                                           Mongólia
# 48                                           Mongólia
# 49                                           Mongolia
# 50                                           Mongolia
# 51                                           Mongolia
# 52                                           Mongolia
# 53                                               モンゴル
# 54                                               モンゴル
# 55                                                 몽골
# 56                                                몽골국
# 57                                           Mongolië
# 58                                           Mongolië
# 59                                           مغولستان
# 60                                           مغولستان
# 61                                           Mongolia
# 62                                           Mongolia
# 63                                           Mongólia
# 64                                           Mongólia
# 65                                           Монголия
# 66                                           Монголия
# 67                                          Mongolsko
# 68                                          Mongolsko
# 69                                           Mongolia
# 70                                           Mongolia
# 71                                          Монголија
# 72                                          Монголија
# 73                                          Mongoliet
# 74                                          Mongoliet
# 75                                         Moğolistan
# 76                                         Moğolistan
# 77                                            منگولیا
# 78                                            منگولیا
# 79                                                 蒙古
# 80                                                 蒙古
# 81                                                 🇲🇳
# 82              https://goo.gl/maps/A1X7bMCKThBDNjzH6
# 83      https://www.openstreetmap.org/relation/161033
# 84                                            3278292
# 85                                               32.7
# 86                                                MNG
# 87                                                MGL
# 88                                              right
# 89                               UTC+07:00, UTC+08:00
# 90                                               Asia
# 91                    https://flagcdn.com/w320/mn.png
# 92                         https://flagcdn.com/mn.svg
# 93  The flag of Mongolia is composed of three equa...
# 94  https://mainfacts.com/media/images/coats_of_ar...
# 95  https://mainfacts.com/media/images/coats_of_ar...
# 96                                             monday
# 97                                      47.92, 106.91
# 98                                             ######
# 99                                          ^(\d{6})$

# %% [markdown]
# Explicacion para algunas de las filas

# %%
# 2. Aplanar el diccionario
def flatten_dict(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            items.append((new_key, ', '.join(str(i) for i in v)))
        else:
            items.append((new_key, v))
    return dict(items)

flat_data = flatten_dict(country)

# 3. Diccionario de descripciones COMPLETAS para Chile
descripciones = {
    "name.common": "Nombre común del país.",
    "name.official": "Nombre oficial del país.",
    "name.nativeName.spa.official": "Nombre oficial en español.",
    "name.nativeName.spa.common": "Nombre común en español.",
    "tld": "Dominio de nivel superior del país.",
    "cca2": "Código ISO 3166-1 alfa-2.",
    "ccn3": "Código numérico ISO 3166-1.",
    "cca3": "Código ISO 3166-1 alfa-3.",
    "cioc": "Código olímpico del país.",
    "independent": "Indica si es un país independiente.",
    "status": "Estatus oficial asignado.",
    "unMember": "Es miembro de las Naciones Unidas.",
    "currencies.CLP.name": "Nombre de la moneda oficial.",
    "currencies.CLP.symbol": "Símbolo de la moneda.",
    "idd.root": "Prefijo raíz telefónico internacional.",
    "idd.suffixes": "Sufijos telefónicos internacionales.",
    "capital": "Capital del país.",
    "altSpellings": "Otras formas de nombrar al país.",
    "region": "Región geográfica (continente).",
    "subregion": "Subregión geográfica.",
    "languages.spa": "Idioma oficial (español).",
    "translations.spa.official": "Traducción oficial al español.",
    "translations.spa.common": "Traducción común al español.",
    "latlng": "Coordenadas de latitud y longitud.",
    "landlocked": "Indica si el país no tiene costa.",
    "borders": "Países con los que comparte frontera.",
    "area": "Área total del país (en km²).",
    "demonyms.eng.m": "Gentilicio masculino en inglés.",
    "demonyms.eng.f": "Gentilicio femenino en inglés.",
    "flag": "Emoji de la bandera del país.",
    "maps.googleMaps": "URL de Google Maps.",
    "maps.openStreetMaps": "URL de OpenStreetMap.",
    "population": "Población total.",
    "gini.2017": "Índice de Gini (desigualdad) en 2017.",
    "fifa": "Código FIFA del país.",
    "car.signs": "Símbolo en matrículas de autos.",
    "car.side": "Lado de conducción (izquierda/derecha).",
    "timezones": "Zonas horarias del país.",
    "continents": "Continente al que pertenece.",
    "flags.png": "URL de la imagen de la bandera (PNG).",
    "flags.svg": "URL de la imagen de la bandera (SVG).",
    "coatOfArms.png": "Escudo de armas (imagen PNG).",
    "coatOfArms.svg": "Escudo de armas (imagen SVG).",
    "startOfWeek": "Día en que comienza la semana.",
    "capitalInfo.latlng": "Coordenadas de la capital.",
    "postalCode.format": "Formato del código postal.",
    "postalCode.regex": "Expresión regular del código postal.",
}

# 4. Construir el DataFrame con descripciones completas
df = pd.DataFrame([
    {
        "Categoría": clave,
        "Valor": valor,
        "Descripción": descripciones[clave]
    }
    for clave, valor in flat_data.items() if clave in descripciones
])

# 5. Mostrar todas las filas
pd.set_option('display.max_rows', None)
df
# Out:
#                     Categoría  \
# 0                 name.common
# 1               name.official
# 2                         tld
# 3                        cca2
# 4                        ccn3
# 5                        cioc
# 6                 independent
# 7                      status
# 8                    unMember
# 9                    idd.root
# 10               idd.suffixes
# 11                    capital
# 12               altSpellings
# 13                     region
# 14                  subregion
# 15                     latlng
# 16                 landlocked
# 17                    borders
# 18                       area
# 19             demonyms.eng.f
# 20             demonyms.eng.m
# 21                       cca3
# 22  translations.spa.official
# 23    translations.spa.common
# 24                       flag
# 25            maps.googleMaps
# 26        maps.openStreetMaps
# 27                 population
# 28                       fifa
# 29                  car.signs
# 30                   car.side
# 31                  timezones
# 32                 continents
# 33                  flags.png
# 34                  flags.svg
# 35             coatOfArms.png
# 36             coatOfArms.svg
# 37                startOfWeek
# 38         capitalInfo.latlng
# 39          postalCode.format
# 40           postalCode.regex
#
#                                                 Valor  \
# 0                                            Mongolia
# 1                                            Mongolia
# 2                                                 .mn
# 3                                                  MN
# 4                                                 496
# 5                                                 MGL
# 6                                                True
# 7                                 officially-assigned
# 8                                                True
# 9                                                  +9
# 10                                                 76
# 11                                         Ulan Bator
# 12                                                 MN
# 13                                               Asia
# 14                                       Eastern Asia
# 15                                        46.0, 105.0
# 16                                               True
# 17                                           CHN, RUS
# 18                                          1564110.0
# 19                                          Mongolian
# 20                                          Mongolian
# 21                                                MNG
# 22                                           Mongolia
# 23                                           Mongolia
# 24                                                 🇲🇳
# 25              https://goo.gl/maps/A1X7bMCKThBDNjzH6
# 26      https://www.openstreetmap.org/relation/161033
# 27                                            3278292
# 28                                                MNG
# 29                                                MGL
# 30                                              right
# 31                               UTC+07:00, UTC+08:00
# 32                                               Asia
# 33                    https://flagcdn.com/w320/mn.png
# 34                         https://flagcdn.com/mn.svg
# 35  https://mainfacts.com/media/images/coats_of_ar...
# 36  https://mainfacts.com/media/images/coats_of_ar...
# 37                                             monday
# 38                                      47.92, 106.91
# 39                                             ######
# 40                                          ^(\d{6})$
#
#                                 Descripción
# 0                    Nombre común del país.
# 1                  Nombre oficial del país.
# 2       Dominio de nivel superior del país.
# 3                 Código ISO 3166-1 alfa-2.
# 4               Código numérico ISO 3166-1.
# 5                 Código olímpico del país.
# 6       Indica si es un país independiente.
# 7                 Estatus oficial asignado.
# 8        Es miembro de las Naciones Unidas.
# 9    Prefijo raíz telefónico internacional.
# 10     Sufijos telefónicos internacionales.
# 11                        Capital del país.
# 12         Otras formas de nombrar al país.
# 13          Región geográfica (continente).
# 14                    Subregión geográfica.
# 15       Coordenadas de latitud y longitud.
# 16        Indica si el país no tiene costa.
# 17    Países con los que comparte frontera.
# 18            Área total del país (en km²).
# 19           Gentilicio femenino en inglés.
# 20          Gentilicio masculino en inglés.
# 21                Código ISO 3166-1 alfa-3.
# 22           Traducción oficial al español.
# 23             Traducción común al español.
# 24            Emoji de la bandera del país.
# 25                      URL de Google Maps.
# 26                    URL de OpenStreetMap.
# 27                         Población total.
# 28                    Código FIFA del país.
# 29          Símbolo en matrículas de autos.
# 30  Lado de conducción (izquierda/derecha).
# 31                 Zonas horarias del país.
# 32             Continente al que pertenece.
# 33    URL de la imagen de la bandera (PNG).
# 34    URL de la imagen de la bandera (SVG).
# 35            Escudo de armas (imagen PNG).
# 36            Escudo de armas (imagen SVG).
# 37           Día en que comienza la semana.
# 38               Coordenadas de la capital.
# 39               Formato del código postal.
# 40     Expresión regular del código postal.
